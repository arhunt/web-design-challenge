# %%
import pandas as pd

# %%
cities2_df = pd.read_csv("cities2.csv",usecols=[1,2,3,4,5,6,7,8])

# %%
cities2_df
# Out:
#              City  Latitude  Longitude  Max Temp  Humidity  Cloudiness  \
# 0          Hobart    -42.88     147.33     41.00        75          36
# 1    Punta Arenas    -53.15     -70.92     37.40        59          20
# 2        Victoria     22.29     114.16     84.00        74         100
# 3           Ishim     56.11      69.49     54.61        90         100
# 4        Zhigansk     66.77     123.37     41.00        84           8
# ..            ...       ...        ...       ...       ...         ...
# 558     Bluefield     37.27     -81.22     78.01        73          20
# 559       Maumere     -8.62     122.21     76.17        76          19
# 560   Serebryansk     49.69      83.29     55.40        71          20
# 561    Libreville      0.39       9.45     82.40        74          40
# 562        Viedma    -40.81     -63.00     64.99        28           8
#
#      Wind Speed Country
# 0          6.93      AU
# 1         26.40      CL
# 2          7.58      HK
# ...

# %%
cities2html = cities2_df.to_html(columns=["City","Country","Latitude","Longitude","Max Temp","Humidity","Cloudiness","Wind Speed"])

# %%
print(cities2html)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>City</th>
#       <th>Country</th>
#       <th>Latitude</th>
#       <th>Longitude</th>
#       <th>Max Temp</th>
#       <th>Humidity</th>
#       <th>Cloudiness</th>
#       <th>Wind Speed</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Hobart</td>
#       <td>AU</td>
#       <td>-42.88</td>
#       <td>147.33</td>
#       <td>41.00</td>
#       <td>75</td>
#       <td>36</td>
#       <td>6.93</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Punta Arenas</td>
#       <td>CL</td>
#       <td>-53.15</td>
#       <td>-70.92</td>
#       <td>37.40</td>
#       <td>59</td>
#       <td>20</td>
#       <td>26.40</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Victoria</td>
#       <td>HK</td>
#       <td>22.29</td>
#       <td>114.16</td>
#       <td>84.00</td>
#       <td>74</td>
#       <td>100</td>
# ...
